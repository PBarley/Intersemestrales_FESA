# %% [markdown]
# ## Sesión 05
#
# ### Procesamiento de Datos con Python
# ### FES Aragon
# ### ICO
# ### Paola Barron Leyva

# %%
import pandas as pd

# %%
df = pd.read_json("datos/alumnos_calif.json")
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                     NaN          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           NaN
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                    NaN                      NaN           5.0
# 11                    NaN                      NaN           5.0
# 12                    NaN                      NaN           5.0
#
#                   curp
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4   GUFC920124HPPTLR04
# 5   JICR920403HSPMRM07
# 6   MARJ930622HQTRVV01
# 7                  NaN
# 8   SUSO911025MDFRNS02
# 9   VAGR900708HQTRNS02
# 10                 NaN
# 11                 NaN
# 12                 NaN

# %%
df['estado'] = df.curp.str[11:13]
df['gpa'] = (((df['calificacion']*100)/df['calificacion'].max())/20) -1
gpa_rango = [1, 1.7, 2.4, 3.3, 4.1]
gpa_etiqueta = ['D', 'C', 'B', 'A']
df['gpa_escala'] = pd.cut(df['gpa'], bins=gpa_rango, labels=gpa_etiqueta)
sti = pd.date_range('2023-01-01', periods=df.clave_alu.count(), freq='2m')
df['fecha'] = sti
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                     NaN          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           NaN
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                    NaN                      NaN           5.0
# 11                    NaN                      NaN           5.0
# 12                    NaN                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df.isnull()
# Out:
#     clave_alu  ap_paterno  ap_materno  nombre   sexo  ciudad  email  \
# 0       False       False       False   False  False   False  False
# 1       False       False       False   False  False   False   True
# 2       False       False       False   False  False   False  False
# 3       False       False       False   False  False   False   True
# 4       False       False       False   False  False   False  False
# 5       False       False       False   False  False   False  False
# 6       False       False       False   False  False    True  False
# 7       False       False       False   False  False   False  False
# 8       False       False       False   False  False   False  False
# 9       False       False       False   False   True   False  False
# 10      False       False       False   False   True    True   True
# 11      False       False       False   False   True    True   True
# 12      False       False       False   False   True    True   True
#
#     calificacion   curp  estado    gpa  gpa_escala  fecha
# 0          False   True    True  False       False  False
# 1          False   True    True  False       False  False
# 2          False   True    True  False       False  False
# 3          False   True    True  False       False  False
# 4          False  False   False  False       False  False
# 5          False  False   False  False       False  False
# 6          False  False   False  False       False  False
# 7          False   True    True  False       False  False
# 8           True  False   False   True        True  False
# 9          False  False   False  False       False  False
# 10         False   True    True  False       False  False
# 11         False   True    True  False       False  False
# 12         False   True    True  False       False  False

# %%
df.isnull().sum()
# Out:
# clave_alu       0
# ap_paterno      0
# ap_materno      0
# nombre          0
# sexo            4
# ciudad          4
# email           5
# calificacion    1
# curp            8
# estado          8
# gpa             1
# gpa_escala      1
# fecha           0
# dtype: int64

# %%
df_na = df.copy()
df_na.dropna()
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 4   11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
#
#                     email  calificacion                curp estado       gpa  \
# 4  chorok_skp91@email.com           5.0  GUFC920124HPPTLR04     PP  1.577320
# 5    ramono555@himail.com           6.2  JICR920403HSPMRM07     SP  2.195876
#
#   gpa_escala      fecha
# 4          D 2023-09-30
# 5          C 2023-11-30

# %%
df_na
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                     NaN          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           NaN
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                    NaN                      NaN           5.0
# 11                    NaN                      NaN           5.0
# 12                    NaN                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df_na.dropna(axis=1)
# Out:
#     clave_alu ap_paterno ap_materno          nombre      fecha
# 0    11030172   BORBOLLA      RAMOS         ARGELIA 2023-01-31
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA 2023-03-31
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO 2023-05-31
# 3    11030178     GARCIA      GOMEZ          RAFAEL 2023-07-31
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID 2023-09-30
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO 2023-11-30
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE 2024-01-31
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN 2024-03-31
# 8    11030201     SUAREZ    SANCHEZ           ROCIO 2024-05-31
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO 2024-07-31
# 10   14080001      MEJIA    JIMENEZ           LUISA 2024-09-30
# 11   14080002      MEJIA    JIMENEZ           LUISA 2024-11-30
# 12   14080003      MEJIA    JIMENEZ           LUISA 2025-01-31

# %%
df_na[df_na['curp'].isnull()]
# Out:
#     clave_alu ap_paterno ap_materno         nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1    11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ         RAFAEL    M
# 7    11030199    ROSALES     APREZA  NESTOR MARTIN    M
# 10   14080001      MEJIA    JIMENEZ          LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ          LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ          LUISA  NaN
#
#                    ciudad                    email  calificacion curp estado  \
# 0               QUERETARO     argi_gogos@email.com           5.0  NaN    NaN
# 1             GUADALAJARA                      NaN           8.7  NaN    NaN
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3  NaN    NaN
# 3          QUERETARO QRO.                      NaN           5.0  NaN    NaN
# 7               QUERETARO     nestoriwh@hotmai.com           5.0  NaN    NaN
# 10                    NaN                      NaN           5.0  NaN    NaN
# 11                    NaN                      NaN           5.0  NaN    NaN
# 12                    NaN                      NaN           5.0  NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 7   1.577320          D 2024-03-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df_na[df_na.isnull().any(axis = 1)]
# Out:
#     clave_alu ap_paterno ap_materno         nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1    11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ         RAFAEL    M
# 6    11030188   MARTINEZ     RIVERA   JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA  NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ          ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ        ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ          LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ          LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ          LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 6                     NaN          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           NaN
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                    NaN                      NaN           5.0
# 11                    NaN                      NaN           5.0
# 12                    NaN                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df_na['ciudad']= df_na.ciudad.fillna('SIN CD')
df_na
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                  SIN CD          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           NaN
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                 SIN CD                      NaN           5.0
# 11                 SIN CD                      NaN           5.0
# 12                 SIN CD                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df_nac=df_na.copy()
df_nac['calificacion'] = round(df_na.calificacion.fillna(df_na.calificacion.mean()), 1)
df_nac
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                  SIN CD          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           6.2
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                 SIN CD                      NaN           5.0
# 11                 SIN CD                      NaN           5.0
# 12                 SIN CD                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df_nac=df_na.copy()
df_nac['calificacion'] = round(df_na.calificacion.fillna(df_na.calificacion.min()), 1)
df_nac
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                  SIN CD          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           5.0
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                 SIN CD                      NaN           5.0
# 11                 SIN CD                      NaN           5.0
# 12                 SIN CD                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df_nac=df_na.copy()
df_nac['calificacion'] = round(df_na.calificacion.fillna(df_na.calificacion.mean()), 3)
df_nac
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com         5.000
# 1             GUADALAJARA                      NaN         8.700
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com         7.300
# 3          QUERETARO QRO.                      NaN         5.000
# 4               QUERETARO   chorok_skp91@email.com         5.000
# 5             GUADALAJARA     ramono555@himail.com         6.200
# 6                  SIN CD          marka@email.com         8.000
# 7               QUERETARO     nestoriwh@hotmai.com         5.000
# 8               QUERETARO         ossuarez@aol.com         6.242
# 9               QUERETARO      rob_vaz03@email.com         9.700
# 10                 SIN CD                      NaN         5.000
# 11                 SIN CD                      NaN         5.000
# 12                 SIN CD                      NaN         5.000
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df_nac=df_na.copy()
df_nac['calificacion'] = round(df_na.calificacion.fillna(df_na.calificacion.min()), 3)
df_nac
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                  SIN CD          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           5.0
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                 SIN CD                      NaN           5.0
# 11                 SIN CD                      NaN           5.0
# 12                 SIN CD                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
#Reemplazar valores
df_nac=df_na.copy()
df_nac['calificacion'] = round(df_na.calificacion.fillna(df_na.calificacion.min()), 1)
df['calificacion'] = round(df.calificacion.fillna(df.calificacion.min()), 1)
df_nac
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     argi_gogos@email.com           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  tavoferrus_11@email.com           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   chorok_skp91@email.com           5.0
# 5             GUADALAJARA     ramono555@himail.com           6.2
# 6                  SIN CD          marka@email.com           8.0
# 7               QUERETARO     nestoriwh@hotmai.com           5.0
# 8               QUERETARO         ossuarez@aol.com           5.0
# 9               QUERETARO      rob_vaz03@email.com           9.7
# 10                 SIN CD                      NaN           5.0
# 11                 SIN CD                      NaN           5.0
# 12                 SIN CD                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
#Reemplazar valores
df['ciudad'] = df['ciudad'].replace({"QUERETARO QRO.":"QUERETARO"})
df['ciudad'] = df['ciudad'].replace({"SANTIAGO DE QUERETARO":"QUERETARO"})
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                       email  calificacion                curp estado  \
# 0      argi_gogos@email.com           5.0                 NaN    NaN
# 1                       NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@email.com           7.3                 NaN    NaN
# 3                       NaN           5.0                 NaN    NaN
# 4    chorok_skp91@email.com           5.0  GUFC920124HPPTLR04     PP
# 5      ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@email.com           8.0  MARJ930622HQTRVV01     QT
# 7      nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8          ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT
# 10                      NaN           5.0                 NaN    NaN
# 11                      NaN           5.0                 NaN    NaN
# 12                      NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30
# 5   2.195876          C 2023-11-30
# 6   3.123711          B 2024-01-31
# 7   1.577320          D 2024-03-31
# 8        NaN        NaN 2024-05-31
# 9   4.000000          A 2024-07-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df['ciudad'] = df['ciudad'].replace({"SANTIAGO DE QUERETARO":"QUERETARO", "QUERETARO QRO.":"QUERETARO"})
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                       email  calificacion                curp estado  \
# 0      argi_gogos@email.com           5.0                 NaN    NaN
# 1                       NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@email.com           7.3                 NaN    NaN
# 3                       NaN           5.0                 NaN    NaN
# 4    chorok_skp91@email.com           5.0  GUFC920124HPPTLR04     PP
# 5      ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@email.com           8.0  MARJ930622HQTRVV01     QT
# 7      nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8          ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT
# 10                      NaN           5.0                 NaN    NaN
# 11                      NaN           5.0                 NaN    NaN
# 12                      NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30
# 5   2.195876          C 2023-11-30
# 6   3.123711          B 2024-01-31
# 7   1.577320          D 2024-03-31
# 8        NaN        NaN 2024-05-31
# 9   4.000000          A 2024-07-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df['email']=df['email'].replace(to_replace="email.com", value="aragon.unam.mx", regex=True)
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 10                           NaN           5.0                 NaN    NaN
# 11                           NaN           5.0                 NaN    NaN
# 12                           NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30
# 5   2.195876          C 2023-11-30
# 6   3.123711          B 2024-01-31
# 7   1.577320          D 2024-03-31
# 8        NaN        NaN 2024-05-31
# 9   4.000000          A 2024-07-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df_na['email']=df_na['email'].str.upper()
df_na
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN
#
#                    ciudad                    email  calificacion  \
# 0               QUERETARO     ARGI_GOGOS@EMAIL.COM           5.0
# 1             GUADALAJARA                      NaN           8.7
# 2   SANTIAGO DE QUERETARO  TAVOFERRUS_11@EMAIL.COM           7.3
# 3          QUERETARO QRO.                      NaN           5.0
# 4               QUERETARO   CHOROK_SKP91@EMAIL.COM           5.0
# 5             GUADALAJARA     RAMONO555@HIMAIL.COM           6.2
# 6                  SIN CD          MARKA@EMAIL.COM           8.0
# 7               QUERETARO     NESTORIWH@HOTMAI.COM           5.0
# 8               QUERETARO         OSSUAREZ@AOL.COM           NaN
# 9               QUERETARO      ROB_VAZ03@EMAIL.COM           9.7
# 10                 SIN CD                      NaN           5.0
# 11                 SIN CD                      NaN           5.0
# 12                 SIN CD                      NaN           5.0
#
#                   curp estado       gpa gpa_escala      fecha
# 0                  NaN    NaN  1.577320          D 2023-01-31
# 1                  NaN    NaN  3.484536          A 2023-03-31
# 2                  NaN    NaN  2.762887          B 2023-05-31
# 3                  NaN    NaN  1.577320          D 2023-07-31
# 4   GUFC920124HPPTLR04     PP  1.577320          D 2023-09-30
# 5   JICR920403HSPMRM07     SP  2.195876          C 2023-11-30
# 6   MARJ930622HQTRVV01     QT  3.123711          B 2024-01-31
# 7                  NaN    NaN  1.577320          D 2024-03-31
# 8   SUSO911025MDFRNS02     DF       NaN        NaN 2024-05-31
# 9   VAGR900708HQTRNS02     QT  4.000000          A 2024-07-31
# 10                 NaN    NaN  1.577320          D 2024-09-30
# 11                 NaN    NaN  1.577320          D 2024-11-30
# 12                 NaN    NaN  1.577320          D 2025-01-31

# %%
df['ciudad'] = df['ciudad'].replace({"SANTIAGO DE QUERETARO":"QUERETARO", "QUERETARO QRO.":"QUERETARO"})
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 10                           NaN           5.0                 NaN    NaN
# 11                           NaN           5.0                 NaN    NaN
# 12                           NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30
# 5   2.195876          C 2023-11-30
# 6   3.123711          B 2024-01-31
# 7   1.577320          D 2024-03-31
# 8        NaN        NaN 2024-05-31
# 9   4.000000          A 2024-07-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df['ciudad']=df['ciudad'].str.strip()
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 10                           NaN           5.0                 NaN    NaN
# 11                           NaN           5.0                 NaN    NaN
# 12                           NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30
# 5   2.195876          C 2023-11-30
# 6   3.123711          B 2024-01-31
# 7   1.577320          D 2024-03-31
# 8        NaN        NaN 2024-05-31
# 9   4.000000          A 2024-07-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# dtype: bool

# %%
s_dup=df.duplicated(subset=['ap_paterno','ap_materno','nombre','sexo','ciudad','email'],keep='last')
s_dup
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# dtype: bool

# %%
df[s_dup]
# Out:
#     clave_alu ap_paterno ap_materno nombre sexo ciudad email  calificacion  \
# 10   14080001      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
# 11   14080002      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
#
#    curp estado      gpa gpa_escala      fecha
# 10  NaN    NaN  1.57732          D 2024-09-30
# 11  NaN    NaN  1.57732          D 2024-11-30

# %%
df.drop_duplicates(subset=['ap_paterno','ap_materno','nombre','sexo','ciudad','email'],keep='last',inplace=True)
df.count()
# Out:
# clave_alu       11
# ap_paterno      11
# ap_materno      11
# nombre          11
# sexo             9
# ciudad           9
# email            8
# calificacion    11
# curp             5
# estado           5
# gpa             10
# gpa_escala      10
# fecha           11
# dtype: int64

# %%
df['ciudad'].unique()
# Out:
# array(['QUERETARO', 'GUADALAJARA', nan], dtype=object)

# %%
df['ciudad'].value_counts(dropna=False)
# Out:
# QUERETARO      7
# GUADALAJARA    2
# NaN            2
# Name: ciudad, dtype: int64

# %%
df['calificacion']>5
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 12    False
# Name: calificacion, dtype: bool

# %%
df[df['calificacion']>5].sort_values(by='calificacion', ascending=False)
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 9   11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 1   11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 6   11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 2   11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
#
#                           email  calificacion                curp estado  \
# 9      rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 1                           NaN           8.7                 NaN    NaN
# 6          marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 2  tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 5          ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
#
#         gpa gpa_escala      fecha
# 9  4.000000          A 2024-07-31
# 1  3.484536          A 2023-03-31
# 6  3.123711          B 2024-01-31
# 2  2.762887          B 2023-05-31
# 5  2.195876          C 2023-11-30

# %%
df[df['calificacion']>5].sort_values(by=["sexo",'calificacion'], ascending=[True,False])
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 1   11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 2   11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 9   11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
#
#                           email  calificacion                curp estado  \
# 1                           NaN           8.7                 NaN    NaN
# 5          ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6          marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 2  tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 9      rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
#
#         gpa gpa_escala      fecha
# 1  3.484536          A 2023-03-31
# 5  2.195876          C 2023-11-30
# 6  3.123711          B 2024-01-31
# 2  2.762887          B 2023-05-31
# 9  4.000000          A 2024-07-31

# %%
filtro_calificacion =df['calificacion']>5
filtro_ciudad = df['ciudad']!= 'QUERETARO'

df[filtro_calificacion&filtro_ciudad].sort_values(by=["sexo",'calificacion'], ascending=[True,False])
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 1   11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
#
#                   email  calificacion                curp estado       gpa  \
# 1                   NaN           8.7                 NaN    NaN  3.484536
# 5  ramono555@himail.com           6.2  JICR920403HSPMRM07     SP  2.195876
# 6  marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT  3.123711
#
#   gpa_escala      fecha
# 1          A 2023-03-31
# 5          C 2023-11-30
# 6          B 2024-01-31

# %%
#filtro por fecha
from datetime import datetime
df[df['fecha']>= datetime(year=2024, month=4,day=1)].sort_values('fecha')
# Out:
#     clave_alu ap_paterno ap_materno   nombre sexo     ciudad  \
# 8    11030201     SUAREZ    SANCHEZ    ROCIO    F  QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ  ROBERTO  NaN  QUERETARO
# 12   14080003      MEJIA    JIMENEZ    LUISA  NaN        NaN
#
#                        email  calificacion                curp estado  \
# 8           ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9   rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                       NaN           5.0                 NaN    NaN
#
#         gpa gpa_escala      fecha
# 8       NaN        NaN 2024-05-31
# 9   4.00000          A 2024-07-31
# 12  1.57732          D 2025-01-31

# %%
df[df['nombre'].isin(['ROBERTO', 'LUISA']) & ~ filtro_calificacion]
# Out:
#     clave_alu ap_paterno ap_materno nombre sexo ciudad email  calificacion  \
# 12   14080003      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
#
#    curp estado      gpa gpa_escala      fecha
# 12  NaN    NaN  1.57732          D 2025-01-31

# %%
df[~df['nombre'].isin(['ROBERTO', 'LUISA']) & filtro_calificacion][['nombre','gpa_escala']]
# Out:
#            nombre gpa_escala
# 1   KARLA MARIANA          A
# 2         OCTAVIO          B
# 5  RAMON HUMBERTO          C
# 6    JAVIER JOSUE          B

# %%
df['lista_email'] = df.email.str.split('@')
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                           NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha                      lista_email
# 0   1.577320          D 2023-01-31     [argi_gogos, aragon.unam.mx]
# 1   3.484536          A 2023-03-31                              NaN
# 2   2.762887          B 2023-05-31  [tavoferrus_11, aragon.unam.mx]
# 3   1.577320          D 2023-07-31                              NaN
# 4   1.577320          D 2023-09-30   [chorok_skp91, aragon.unam.mx]
# 5   2.195876          C 2023-11-30          [ramono555, himail.com]
# 6   3.123711          B 2024-01-31          [marka, aragon.unam.mx]
# 7   1.577320          D 2024-03-31          [nestoriwh, hotmai.com]
# 8        NaN        NaN 2024-05-31              [ossuarez, aol.com]
# 9   4.000000          A 2024-07-31      [rob_vaz03, aragon.unam.mx]
# 12  1.577320          D 2025-01-31                              NaN

# %%
df['lista_email'].tolist()
# Out:
# [['argi_gogos', 'aragon.unam.mx'],
#  nan,
#  ['tavoferrus_11', 'aragon.unam.mx'],
#  nan,
#  ['chorok_skp91', 'aragon.unam.mx'],
#  ['ramono555', 'himail.com'],
#  ['marka', 'aragon.unam.mx'],
#  ['nestoriwh', 'hotmai.com'],
#  ['ossuarez', 'aol.com'],
#  ['rob_vaz03', 'aragon.unam.mx'],
#  nan]

# %%
df['lista_email'].fillna('', inplace=True)
print(df['lista_email'].map(len).max())
df['lista_email']
# Out:
# 2
# 0        [argi_gogos, aragon.unam.mx]
# 1
# 2     [tavoferrus_11, aragon.unam.mx]
# 3
# 4      [chorok_skp91, aragon.unam.mx]
# 5             [ramono555, himail.com]
# 6             [marka, aragon.unam.mx]
# 7             [nestoriwh, hotmai.com]
# 8                 [ossuarez, aol.com]
# 9         [rob_vaz03, aragon.unam.mx]
# 12
# Name: lista_email, dtype: object

# %%
df_mail = pd.DataFrame(df['lista_email'].fillna('').tolist()).add_prefix('email_')
df_mail
# Out:
#           email_0         email_1
# 0      argi_gogos  aragon.unam.mx
# 1            None            None
# 2   tavoferrus_11  aragon.unam.mx
# 3            None            None
# 4    chorok_skp91  aragon.unam.mx
# 5       ramono555      himail.com
# 6           marka  aragon.unam.mx
# 7       nestoriwh      hotmai.com
# 8        ossuarez         aol.com
# 9       rob_vaz03  aragon.unam.mx
# 10           None            None

# %%
df_concat = pd.concat([df,df_mail], axis=1)
df_concat
# Out:
#      clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0   11030172.0   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1   11030173.0     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2   11030177.0   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3   11030178.0     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4   11030180.0  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5   11030183.0    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188.0   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7   11030199.0    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8   11030201.0     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9   11030204.0    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 12  14080003.0      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 10         NaN        NaN        NaN             NaN  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                           NaN           5.0                 NaN    NaN
# 10                           NaN           NaN                 NaN    NaN
#
#          gpa gpa_escala      fecha                      lista_email  \
# 0   1.577320          D 2023-01-31     [argi_gogos, aragon.unam.mx]
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31  [tavoferrus_11, aragon.unam.mx]
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30   [chorok_skp91, aragon.unam.mx]
# 5   2.195876          C 2023-11-30          [ramono555, himail.com]
# 6   3.123711          B 2024-01-31          [marka, aragon.unam.mx]
# 7   1.577320          D 2024-03-31          [nestoriwh, hotmai.com]
# 8        NaN        NaN 2024-05-31              [ossuarez, aol.com]
# 9   4.000000          A 2024-07-31      [rob_vaz03, aragon.unam.mx]
# 12  1.577320          D 2025-01-31
# 10       NaN        NaN        NaT                              NaN
#
#           email_0         email_1
# 0      argi_gogos  aragon.unam.mx
# 1            None            None
# 2   tavoferrus_11  aragon.unam.mx
# 3            None            None
# 4    chorok_skp91  aragon.unam.mx
# 5       ramono555      himail.com
# 6           marka  aragon.unam.mx
# 7       nestoriwh      hotmai.com
# 8        ossuarez         aol.com
# 9       rob_vaz03  aragon.unam.mx
# 12            NaN             NaN
# 10           None            None

# %%
df_concat.drop(['lista_email'], axis=1, inplace=True)
df_concat.rename(columns={'email_0':'usuario', 'email_1':'dominio'}, inplace=True)
df_concat
# Out:
#      clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0   11030172.0   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1   11030173.0     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2   11030177.0   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3   11030178.0     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4   11030180.0  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5   11030183.0    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188.0   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7   11030199.0    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8   11030201.0     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9   11030204.0    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 12  14080003.0      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 10         NaN        NaN        NaN             NaN  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                           NaN           5.0                 NaN    NaN
# 10                           NaN           NaN                 NaN    NaN
#
#          gpa gpa_escala      fecha        usuario         dominio
# 0   1.577320          D 2023-01-31     argi_gogos  aragon.unam.mx
# 1   3.484536          A 2023-03-31           None            None
# 2   2.762887          B 2023-05-31  tavoferrus_11  aragon.unam.mx
# 3   1.577320          D 2023-07-31           None            None
# 4   1.577320          D 2023-09-30   chorok_skp91  aragon.unam.mx
# 5   2.195876          C 2023-11-30      ramono555      himail.com
# 6   3.123711          B 2024-01-31          marka  aragon.unam.mx
# 7   1.577320          D 2024-03-31      nestoriwh      hotmai.com
# 8        NaN        NaN 2024-05-31       ossuarez         aol.com
# 9   4.000000          A 2024-07-31      rob_vaz03  aragon.unam.mx
# 12  1.577320          D 2025-01-31            NaN             NaN
# 10       NaN        NaN        NaT           None            None

# %%
df.groupby(['estado'],dropna=False)['clave_alu'].agg('count')
# Out:
# estado
# DF     1
# PP     1
# QT     2
# SP     1
# NaN    6
# Name: clave_alu, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pd.merge(df,df_estado, left_on='estado', right_on='ABREVIATURA', how='inner')
#
# NameError: name 'df_estado' is not defined

# %%
#LEFT muestra todo lo de la izquierda aunque no coincida la llave
pd.merge(df,df_estado, left_on='estado', right_on='ABREVIATURA', how='left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 #LEFT muestra todo lo de la izquierda aunque no coincida la llave
# ----> 2 pd.merge(df,df_estado, left_on='estado', right_on='ABREVIATURA', how='left')
#
# NameError: name 'df_estado' is not defined

# %%
#Right muestra todo lo de la derecha aunque no coincida con la llave
pd.merge(df, df_estado, left_on="estado", right_on="ABREVIATURA", how="right")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 #Right muestra todo lo de la derecha aunque no coincida con la llave
# ----> 2 pd.merge(df, df_estado, left_on="estado", right_on="ABREVIATURA", how="right")
#
# NameError: name 'df_estado' is not defined

# %%
#Outer muestra todo aunque no coincida con la llave
pd.merge(df, df_estado, left_on="estado", right_on="ABREVIATURA", how="outer")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 #Outer muestra todo aunque no coincida con la llave
# ----> 2 pd.merge(df, df_estado, left_on="estado", right_on="ABREVIATURA", how="outer")
#
# NameError: name 'df_estado' is not defined

# %%
# Drop los valores duplicados
df.drop_duplicates(subset=['ap_paterno','ap_materno','nombre','sexo','ciudad','email'], keep='last', implace=True)
df.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Drop los valores duplicados
# ----> 2 df.drop_duplicates(subset=['ap_paterno','ap_materno','nombre','sexo','ciudad','email'], keep='last', implace=True)
#       3 df.count()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: DataFrame.drop_duplicates() got an unexpected keyword argument 'implace'

# %%
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 10   14080001      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 11   14080002      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                       email  calificacion                curp estado  \
# 0      argi_gogos@email.com           5.0                 NaN    NaN
# 1                       NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@email.com           7.3                 NaN    NaN
# 3                       NaN           5.0                 NaN    NaN
# 4    chorok_skp91@email.com           5.0  GUFC920124HPPTLR04     PP
# 5      ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@email.com           8.0  MARJ930622HQTRVV01     QT
# 7      nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8          ossuarez@aol.com           NaN  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT
# 10                      NaN           5.0                 NaN    NaN
# 11                      NaN           5.0                 NaN    NaN
# 12                      NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha
# 0   1.577320          D 2023-01-31
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30
# 5   2.195876          C 2023-11-30
# 6   3.123711          B 2024-01-31
# 7   1.577320          D 2024-03-31
# 8        NaN        NaN 2024-05-31
# 9   4.000000          A 2024-07-31
# 10  1.577320          D 2024-09-30
# 11  1.577320          D 2024-11-30
# 12  1.577320          D 2025-01-31

# %%
df['ciudad'].unique()
# Out:
# array(['QUERETARO', 'GUADALAJARA', nan], dtype=object)

# %%
#Ver la frecuencia de valores unicos de una columna
df['ciudad'].value_counts(dropna=False)
# Out:
# QUERETARO      7
# NaN            4
# GUADALAJARA    2
# Name: ciudad, dtype: int64

# %%
#Filtrar y ordenar
df[df['calificacion'] > 5].sort_values(by='calificacion',ascending=False)
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 9   11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 1   11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 6   11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 2   11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
#
#                      email  calificacion                curp estado       gpa  \
# 9      rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT  4.000000
# 1                      NaN           8.7                 NaN    NaN  3.484536
# 6          marka@email.com           8.0  MARJ930622HQTRVV01     QT  3.123711
# 2  tavoferrus_11@email.com           7.3                 NaN    NaN  2.762887
# 5     ramono555@himail.com           6.2  JICR920403HSPMRM07     SP  2.195876
#
#   gpa_escala      fecha
# 9          A 2024-07-31
# 1          A 2023-03-31
# 6          B 2024-01-31
# 2          B 2023-05-31
# 5          C 2023-11-30

# %%
#Filtrar y ordenar
df[df['calificacion'] > 5].sort_values(by=['sexo', 'calificacion'],ascending=[True, False])
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 1   11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 2   11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 9   11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
#
#                      email  calificacion                curp estado       gpa  \
# 1                      NaN           8.7                 NaN    NaN  3.484536
# 5     ramono555@himail.com           6.2  JICR920403HSPMRM07     SP  2.195876
# 6          marka@email.com           8.0  MARJ930622HQTRVV01     QT  3.123711
# 2  tavoferrus_11@email.com           7.3                 NaN    NaN  2.762887
# 9      rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT  4.000000
#
#   gpa_escala      fecha
# 1          A 2023-03-31
# 5          C 2023-11-30
# 6          B 2024-01-31
# 2          B 2023-05-31
# 9          A 2024-07-31

# %%
filtro_calificacion = df['calificacion'] > 5
#filtro_ciudad = not(df['ciudad'].isnull)
filtro_ciudad = df['ciudad'] !='QUERETARO'

# %%
#Filtrar y ordenar
df[df['calificacion'] > 5].sort_values(by=['ciudad', 'calificacion'],ascending=[True, False])
# Out:
#    clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 1   11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 5   11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 9   11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 2   11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 6   11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
#
#                      email  calificacion                curp estado       gpa  \
# 1                      NaN           8.7                 NaN    NaN  3.484536
# 5     ramono555@himail.com           6.2  JICR920403HSPMRM07     SP  2.195876
# 9      rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT  4.000000
# 2  tavoferrus_11@email.com           7.3                 NaN    NaN  2.762887
# 6          marka@email.com           8.0  MARJ930622HQTRVV01     QT  3.123711
#
#   gpa_escala      fecha
# 1          A 2023-03-31
# 5          C 2023-11-30
# 9          A 2024-07-31
# 2          B 2023-05-31
# 6          B 2024-01-31

# %%
#Filtro por fecha
from datetime import datetime
df[df['fecha'] >= datetime(year=2024, month=4, day=1)].sort_values(by='fecha')
# Out:
#     clave_alu ap_paterno ap_materno   nombre sexo     ciudad  \
# 8    11030201     SUAREZ    SANCHEZ    ROCIO    F  QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ  ROBERTO  NaN  QUERETARO
# 10   14080001      MEJIA    JIMENEZ    LUISA  NaN        NaN
# 11   14080002      MEJIA    JIMENEZ    LUISA  NaN        NaN
# 12   14080003      MEJIA    JIMENEZ    LUISA  NaN        NaN
#
#                   email  calificacion                curp estado      gpa  \
# 8      ossuarez@aol.com           NaN  SUSO911025MDFRNS02     DF      NaN
# 9   rob_vaz03@email.com           9.7  VAGR900708HQTRNS02     QT  4.00000
# 10                  NaN           5.0                 NaN    NaN  1.57732
# 11                  NaN           5.0                 NaN    NaN  1.57732
# 12                  NaN           5.0                 NaN    NaN  1.57732
#
#    gpa_escala      fecha
# 8         NaN 2024-05-31
# 9           A 2024-07-31
# 10          D 2024-09-30
# 11          D 2024-11-30
# 12          D 2025-01-31

# %%
df[df['nombre'].isin(['ROBERTO', 'LUISA']) & ~ filtro_calificacion]
# Out:
#     clave_alu ap_paterno ap_materno nombre sexo ciudad email  calificacion  \
# 12   14080003      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
#
#    curp estado      gpa gpa_escala      fecha lista_email
# 12  NaN    NaN  1.57732          D 2025-01-31

# %%
df[~df['nombre'].isin(['ROBERTO', 'LUISA']) & filtro_calificacion][['nombre','gpa_escala']]
# Out:
#            nombre gpa_escala
# 1   KARLA MARIANA          A
# 2         OCTAVIO          B
# 5  RAMON HUMBERTO          C
# 6    JAVIER JOSUE          B

# %%
df['lista_email'] = df.email.str.split('@')
df
# Out:
#     clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0    11030172   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1    11030173     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2    11030177   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3    11030178     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4    11030180  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5    11030183    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6    11030188   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7    11030199    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8    11030201     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9    11030204    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 12   14080003      MEJIA    JIMENEZ           LUISA  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                           NaN           5.0                 NaN    NaN
#
#          gpa gpa_escala      fecha                      lista_email
# 0   1.577320          D 2023-01-31     [argi_gogos, aragon.unam.mx]
# 1   3.484536          A 2023-03-31                              NaN
# 2   2.762887          B 2023-05-31  [tavoferrus_11, aragon.unam.mx]
# 3   1.577320          D 2023-07-31                              NaN
# 4   1.577320          D 2023-09-30   [chorok_skp91, aragon.unam.mx]
# 5   2.195876          C 2023-11-30          [ramono555, himail.com]
# 6   3.123711          B 2024-01-31          [marka, aragon.unam.mx]
# 7   1.577320          D 2024-03-31          [nestoriwh, hotmai.com]
# 8        NaN        NaN 2024-05-31              [ossuarez, aol.com]
# 9   4.000000          A 2024-07-31      [rob_vaz03, aragon.unam.mx]
# 12  1.577320          D 2025-01-31                              NaN

# %%
df['lista_email'].tolist()
# Out:
# [['argi_gogos', 'aragon.unam.mx'],
#  nan,
#  ['tavoferrus_11', 'aragon.unam.mx'],
#  nan,
#  ['chorok_skp91', 'aragon.unam.mx'],
#  ['ramono555', 'himail.com'],
#  ['marka', 'aragon.unam.mx'],
#  ['nestoriwh', 'hotmai.com'],
#  ['ossuarez', 'aol.com'],
#  ['rob_vaz03', 'aragon.unam.mx'],
#  nan]

# %%
df['lista_email'].fillna('', inplace=True)
print(df['lista_email'].map(len).max())
df['lista_email']
# Out:
# 2
# 0        [argi_gogos, aragon.unam.mx]
# 1
# 2     [tavoferrus_11, aragon.unam.mx]
# 3
# 4      [chorok_skp91, aragon.unam.mx]
# 5             [ramono555, himail.com]
# 6             [marka, aragon.unam.mx]
# 7             [nestoriwh, hotmai.com]
# 8                 [ossuarez, aol.com]
# 9         [rob_vaz03, aragon.unam.mx]
# 12
# Name: lista_email, dtype: object

# %%
df_mail = pd.DataFrame(df['lista_email'].fillna('').tolist()).add_prefix('email_')
df_mail
# Out:
#           email_0         email_1
# 0      argi_gogos  aragon.unam.mx
# 1            None            None
# 2   tavoferrus_11  aragon.unam.mx
# 3            None            None
# 4    chorok_skp91  aragon.unam.mx
# 5       ramono555      himail.com
# 6           marka  aragon.unam.mx
# 7       nestoriwh      hotmai.com
# 8        ossuarez         aol.com
# 9       rob_vaz03  aragon.unam.mx
# 10           None            None

# %%
df_concat = pd.concat([df,df_mail], axis=1)
df_concat
# Out:
#      clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0   11030172.0   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1   11030173.0     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2   11030177.0   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3   11030178.0     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4   11030180.0  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5   11030183.0    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188.0   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7   11030199.0    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8   11030201.0     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9   11030204.0    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 12  14080003.0      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 10         NaN        NaN        NaN             NaN  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                           NaN           5.0                 NaN    NaN
# 10                           NaN           NaN                 NaN    NaN
#
#          gpa gpa_escala      fecha                      lista_email  \
# 0   1.577320          D 2023-01-31     [argi_gogos, aragon.unam.mx]
# 1   3.484536          A 2023-03-31
# 2   2.762887          B 2023-05-31  [tavoferrus_11, aragon.unam.mx]
# 3   1.577320          D 2023-07-31
# 4   1.577320          D 2023-09-30   [chorok_skp91, aragon.unam.mx]
# 5   2.195876          C 2023-11-30          [ramono555, himail.com]
# 6   3.123711          B 2024-01-31          [marka, aragon.unam.mx]
# 7   1.577320          D 2024-03-31          [nestoriwh, hotmai.com]
# 8        NaN        NaN 2024-05-31              [ossuarez, aol.com]
# 9   4.000000          A 2024-07-31      [rob_vaz03, aragon.unam.mx]
# 12  1.577320          D 2025-01-31
# 10       NaN        NaN        NaT                              NaN
#
#           email_0         email_1
# 0      argi_gogos  aragon.unam.mx
# 1            None            None
# 2   tavoferrus_11  aragon.unam.mx
# 3            None            None
# 4    chorok_skp91  aragon.unam.mx
# 5       ramono555      himail.com
# 6           marka  aragon.unam.mx
# 7       nestoriwh      hotmai.com
# 8        ossuarez         aol.com
# 9       rob_vaz03  aragon.unam.mx
# 12            NaN             NaN
# 10           None            None

# %%
df_concat.drop(['lista_email'], axis=1, inplace=True)
df_concat.rename(columns={'email_0':'usuario', 'email_1':'dominio'}, inplace=True)
df_concat
# Out:
#      clave_alu ap_paterno ap_materno          nombre sexo       ciudad  \
# 0   11030172.0   BORBOLLA      RAMOS         ARGELIA    F    QUERETARO
# 1   11030173.0     CASTRO    MANCERA   KARLA MARIANA    F  GUADALAJARA
# 2   11030177.0   FERRUSCA    ANDRADE         OCTAVIO    M    QUERETARO
# 3   11030178.0     GARCIA      GOMEZ          RAFAEL    M    QUERETARO
# 4   11030180.0  GUTIERREZ     FLORES    CARLOS DAVID    M    QUERETARO
# 5   11030183.0    JIMENEZ   CARRILLO  RAMON HUMBERTO    F  GUADALAJARA
# 6   11030188.0   MARTINEZ     RIVERA    JAVIER JOSUE    M          NaN
# 7   11030199.0    ROSALES     APREZA   NESTOR MARTIN    M    QUERETARO
# 8   11030201.0     SUAREZ    SANCHEZ           ROCIO    F    QUERETARO
# 9   11030204.0    VAZQUEZ   GONZALEZ         ROBERTO  NaN    QUERETARO
# 12  14080003.0      MEJIA    JIMENEZ           LUISA  NaN          NaN
# 10         NaN        NaN        NaN             NaN  NaN          NaN
#
#                            email  calificacion                curp estado  \
# 0      argi_gogos@aragon.unam.mx           5.0                 NaN    NaN
# 1                            NaN           8.7                 NaN    NaN
# 2   tavoferrus_11@aragon.unam.mx           7.3                 NaN    NaN
# 3                            NaN           5.0                 NaN    NaN
# 4    chorok_skp91@aragon.unam.mx           5.0  GUFC920124HPPTLR04     PP
# 5           ramono555@himail.com           6.2  JICR920403HSPMRM07     SP
# 6           marka@aragon.unam.mx           8.0  MARJ930622HQTRVV01     QT
# 7           nestoriwh@hotmai.com           5.0                 NaN    NaN
# 8               ossuarez@aol.com           5.0  SUSO911025MDFRNS02     DF
# 9       rob_vaz03@aragon.unam.mx           9.7  VAGR900708HQTRNS02     QT
# 12                           NaN           5.0                 NaN    NaN
# 10                           NaN           NaN                 NaN    NaN
#
#          gpa gpa_escala      fecha        usuario         dominio
# 0   1.577320          D 2023-01-31     argi_gogos  aragon.unam.mx
# 1   3.484536          A 2023-03-31           None            None
# 2   2.762887          B 2023-05-31  tavoferrus_11  aragon.unam.mx
# 3   1.577320          D 2023-07-31           None            None
# 4   1.577320          D 2023-09-30   chorok_skp91  aragon.unam.mx
# 5   2.195876          C 2023-11-30      ramono555      himail.com
# 6   3.123711          B 2024-01-31          marka  aragon.unam.mx
# 7   1.577320          D 2024-03-31      nestoriwh      hotmai.com
# 8        NaN        NaN 2024-05-31       ossuarez         aol.com
# 9   4.000000          A 2024-07-31      rob_vaz03  aragon.unam.mx
# 12  1.577320          D 2025-01-31            NaN             NaN
# 10       NaN        NaN        NaT           None            None

# %%
df.groupby(['estado'],dropna=False)['clave_alu'].agg('count')
# Out:
# estado
# DF     1
# PP     1
# QT     2
# SP     1
# NaN    6
# Name: clave_alu, dtype: int64

# %%
df_estado = pd.read_csv("estados_curp.csv")
df_estado

# %%
pd.merge(df,df_estado, left_on='estado', right_on='ABREVIATURA', how='inner')

# %%
pd.merge(df,df_estado, left_on='estado', right_on='ABREVIATURA', how='left')

# %%
pd.merge(df, df_estado, left_on="estado", right_on="ABREVIATURA", how="right")

# %%
pd.merge(df, df_estado, left_on="estado", right_on="ABREVIATURA", how="outer")
